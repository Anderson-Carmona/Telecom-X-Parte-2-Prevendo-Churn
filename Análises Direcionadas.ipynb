# %%
Investigue como variáveis específicas se relacionam com a evasão, como:
•	Tempo de contrato × Evasão
•	Total gasto × Evasão
Utilize gráficos como boxplots ou dispersão (scatter plots) para visualizar padrões e possíveis tendências.
Para aprofundar a investigação sobre a evasão (Churn), vamos analisar como o comportamento financeiro e a fidelidade do cliente (tempo de contrato) influenciam a decisão de sair da empresa.
Nesta etapa, o uso de Boxplots é ideal para comparar a distribuição de uma variável numérica entre dois grupos (Quem saiu vs. Quem ficou), enquanto o Gráfico de Dispersão ajuda a ver a relação entre duas variáveis numéricas simultaneamente.
________________________________________
⏳ 1. Tempo de Contrato (Tenure) × Evasão
O tempo de contrato é um dos principais indicadores de lealdade. Clientes com pouco tempo de casa costumam apresentar maior risco de saída.
•	O que observar: Se a mediana do tempo de contrato dos clientes que evadiram (Churn = Sim) for significativamente menor que a dos clientes que permaneceram.
•	Insight esperado: Geralmente, existe um "período crítico" (ex: os primeiros 6 meses) onde a taxa de evasão é mais alta.
💰 2. Total Gasto (Total Charges) × Evasão
Aqui analisamos o valor acumulado que o cliente trouxe para a empresa. Esta variável é um reflexo direto do tempo de permanência e do valor mensal.
•	Tendência de Evasão: É comum notar que clientes que evadem têm um "Total Gasto" acumulado menor, justamente por terem saído precocemente.
•	Outliers: Fique atento a clientes com alto gasto total que evadiram. Eles representam a perda de clientes "Premium" ou de longo prazo, o que é mais custoso para o negócio.
📉 3. Gráfico de Dispersão: Tempo de Contrato × Total Gasto
Ao cruzar essas duas variáveis colorindo os pontos pelo status de evasão, conseguimos identificar padrões geográficos no gráfico:
•	Zona de Risco: Canto inferior esquerdo (Baixo tempo de contrato e baixo gasto total). Se houver muitos pontos de evasão aqui, o problema é na integração (onboarding).
•	Zona de Alerta: Pontos de evasão que aparecem no canto superior direito (Alto tempo e alto gasto). Isso indica que mesmo clientes fiéis estão saindo, possivelmente por ações da concorrência ou falhas de atendimento recente.
________________________________________
🔍 Resumo de Descobertas Hipotéticas
Relação Analisada	Padrão Comum	Ação Sugerida
Tempo Curto + Evasão	Problema na expectativa do produto ou primeiros passos.	Melhorar o suporte nos primeiros 90 dias.
Gasto Mensal Alto + Evasão	Clientes sensíveis a preço ou buscando benefícios melhores.	Oferecer planos de fidelidade ou descontos progressivos.
Gasto Total Baixo + Evasão	Clientes que nem chegaram a "maturar" na base.	Revisar o perfil de vendas (evitar clientes fora do alvo).
# Out:
#   File "/tmp/ipython-input-1545110452.py", line 2
#     •	Tempo de contrato × Evasão
#     ^
# SyntaxError: invalid character '•' (U+2022)
